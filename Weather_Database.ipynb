# %%
# Import the dependencies.

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        
        cities.append(city)

# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 779

# %%
# Import the requests library.

import requests

# Import the API key.

from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")

print("-----------------------------")


# Create counters.

record_count = 1

set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1

    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1
    
# Run an API request for each of the cities.
    
    try:
        
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
        
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        
        city_data.append({"City": city.title(),
                          
                          "Country": city_country,
                          
                          "Lat": city_lat,
                          
                          "Lng": city_lng,
                          
                          "Max Temp": city_max_temp,
                          
                          "Humidity": city_humidity,
                          
                          "Cloudiness": city_clouds,
                          
                          "Wind Speed": city_wind,
                          
                          "Current Description": city_description})
        

# If an error is experienced, skip the city.
    
    except:
        
        print("City not found. Skipping...")
        
        pass

# Indicate that Data Loading is complete.

print("-----------------------------")

print("Data Retrieval Complete      ")

print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mount isa
# Processing Record 2 of Set 1 | kahului
# Processing Record 3 of Set 1 | hoa binh
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | sao joao da barra
# Processing Record 7 of Set 1 | coahuayana
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | ixtapa
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | delray beach
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | soto la marina
# Processing Record 16 of Set 1 | palmer
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | san carlos de bariloche
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | wanparti
# Processing Record 21 of Set 1 | camana
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | nguru
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | hebertville
# City not found. Skipping...
# Processing Record 30 of Set 1 | paungde
# Processing Record 31 of Set 1 | warrnambool
# Processing Record 32 of Set 1 | constitucion
# Processing Record 33 of Set 1 | aktanysh
# Processing Record 34 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | cabo san lucas
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 1 | samarai
# Processing Record 40 of Set 1 | xiuyan
# Processing Record 41 of Set 1 | liaoyang
# Processing Record 42 of Set 1 | pacific grove
# Processing Record 43 of Set 1 | dakar
# Processing Record 44 of Set 1 | san pedro
# Processing Record 45 of Set 1 | daru
# Processing Record 46 of Set 1 | labuhan
# Processing Record 47 of Set 1 | danville
# Processing Record 48 of Set 1 | camacha
# Processing Record 49 of Set 1 | wanning
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | saint-augustin
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | sao miguel do araguaia
# Processing Record 4 of Set 2 | kindu
# Processing Record 5 of Set 2 | lagoa
# Processing Record 6 of Set 2 | palana
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | carutapera
# Processing Record 10 of Set 2 | fortuna
# Processing Record 11 of Set 2 | ewa beach
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | dhana
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | los llanos de aridane
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | dwarka
# Processing Record 20 of Set 2 | havre-saint-pierre
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 2 | mpongwe
# Processing Record 25 of Set 2 | takoradi
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | richards bay
# Processing Record 29 of Set 2 | krutinka
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | esperance
# Processing Record 32 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 33 of Set 2 | monte alegre
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | grand gaube
# Processing Record 36 of Set 2 | astana
# Processing Record 37 of Set 2 | adrar
# Processing Record 38 of Set 2 | muros
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | hamilton
# Processing Record 42 of Set 2 | yanam
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | faanui
# Processing Record 45 of Set 2 | valle de allende
# Processing Record 46 of Set 2 | kununurra
# Processing Record 47 of Set 2 | cayenne
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | san cristobal
# Processing Record 50 of Set 2 | saskylakh
# Processing Record 1 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 2 of Set 3 | zemio
# Processing Record 3 of Set 3 | bathsheba
# Processing Record 4 of Set 3 | carnarvon
# Processing Record 5 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | miranorte
# City not found. Skipping...
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | alice springs
# Processing Record 10 of Set 3 | yellowknife
# Processing Record 11 of Set 3 | bethel
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | agadez
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | lixourion
# Processing Record 17 of Set 3 | bac lieu
# Processing Record 18 of Set 3 | svetlograd
# Processing Record 19 of Set 3 | mount gambier
# Processing Record 20 of Set 3 | valparaiso
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | samut songkhram
# Processing Record 24 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 3 | lorengau
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | dongsheng
# Processing Record 28 of Set 3 | jumla
# Processing Record 29 of Set 3 | zouxian
# City not found. Skipping...
# Processing Record 30 of Set 3 | butterworth
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | olavarria
# Processing Record 33 of Set 3 | tigil
# Processing Record 34 of Set 3 | port lincoln
# Processing Record 35 of Set 3 | shubarshi
# Processing Record 36 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 3 | broome
# Processing Record 38 of Set 3 | cedar city
# Processing Record 39 of Set 3 | genhe
# Processing Record 40 of Set 3 | pedernales
# Processing Record 41 of Set 3 | la ronge
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | sao joao dos patos
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | deutschlandsberg
# Processing Record 46 of Set 3 | makakilo city
# Processing Record 47 of Set 3 | katsuura
# Processing Record 48 of Set 3 | anaco
# Processing Record 49 of Set 3 | moyo
# Processing Record 50 of Set 3 | bambous virieux
# Processing Record 1 of Set 4 | xingyi
# Processing Record 2 of Set 4 | virginia beach
# Processing Record 3 of Set 4 | russas
# Processing Record 4 of Set 4 | shaoyang
# Processing Record 5 of Set 4 | jha jha
# Processing Record 6 of Set 4 | albany
# Processing Record 7 of Set 4 | saldanha
# Processing Record 8 of Set 4 | salalah
# Processing Record 9 of Set 4 | jadu
# Processing Record 10 of Set 4 | souillac
# Processing Record 11 of Set 4 | turayf
# Processing Record 12 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 4 | bukachacha
# Processing Record 14 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 4 | coihueco
# Processing Record 16 of Set 4 | novikovo
# Processing Record 17 of Set 4 | surgana
# Processing Record 18 of Set 4 | egvekinot
# Processing Record 19 of Set 4 | balkanabat
# Processing Record 20 of Set 4 | isangel
# Processing Record 21 of Set 4 | mahebourg
# Processing Record 22 of Set 4 | vanimo
# Processing Record 23 of Set 4 | bubaque
# Processing Record 24 of Set 4 | birjand
# Processing Record 25 of Set 4 | lipovtsy
# Processing Record 26 of Set 4 | saint-francois
# Processing Record 27 of Set 4 | pangnirtung
# Processing Record 28 of Set 4 | altay
# Processing Record 29 of Set 4 | mocuba
# Processing Record 30 of Set 4 | zhenlai
# Processing Record 31 of Set 4 | norman wells
# Processing Record 32 of Set 4 | ocos
# Processing Record 33 of Set 4 | oranjemund
# Processing Record 34 of Set 4 | guerrero negro
# Processing Record 35 of Set 4 | marshall
# Processing Record 36 of Set 4 | wanaka
# Processing Record 37 of Set 4 | muriti
# Processing Record 38 of Set 4 | tautira
# Processing Record 39 of Set 4 | alamos
# Processing Record 40 of Set 4 | ovalle
# Processing Record 41 of Set 4 | chokurdakh
# Processing Record 42 of Set 4 | naruto
# Processing Record 43 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 4 | nikolsk
# Processing Record 45 of Set 4 | coquimbo
# Processing Record 46 of Set 4 | skibbereen
# Processing Record 47 of Set 4 | lebu
# Processing Record 48 of Set 4 | mitsamiouli
# Processing Record 49 of Set 4 | jinchang
# Processing Record 50 of Set 4 | komsomolskiy
# Processing Record 1 of Set 5 | trofors
# Processing Record 2 of Set 5 | ilulissat
# Processing Record 3 of Set 5 | ulaangom
# Processing Record 4 of Set 5 | leshukonskoye
# Processing Record 5 of Set 5 | dutse
# Processing Record 6 of Set 5 | jacareacanga
# Processing Record 7 of Set 5 | ocala
# Processing Record 8 of Set 5 | saint-pierre
# Processing Record 9 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 5 | klaksvik
# Processing Record 11 of Set 5 | lukhovitsy
# Processing Record 12 of Set 5 | nizhniy bestyakh
# Processing Record 13 of Set 5 | loanda
# Processing Record 14 of Set 5 | barrow
# Processing Record 15 of Set 5 | nazarovo
# Processing Record 16 of Set 5 | ribeira grande
# Processing Record 17 of Set 5 | yulara
# Processing Record 18 of Set 5 | sicamous
# Processing Record 19 of Set 5 | aykhal
# Processing Record 20 of Set 5 | lompoc
# Processing Record 21 of Set 5 | mecca
# Processing Record 22 of Set 5 | grindavik
# Processing Record 23 of Set 5 | antalaha
# Processing Record 24 of Set 5 | kulhudhuffushi
# Processing Record 25 of Set 5 | asau
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | salta
# Processing Record 28 of Set 5 | alpinopolis
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | sao paulo de olivenca
# Processing Record 31 of Set 5 | hami
# Processing Record 32 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 5 | zeerust
# Processing Record 34 of Set 5 | sambava
# Processing Record 35 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 5 | vryburg
# Processing Record 37 of Set 5 | port hedland
# Processing Record 38 of Set 5 | airai
# Processing Record 39 of Set 5 | jogbani
# Processing Record 40 of Set 5 | kavaratti
# Processing Record 41 of Set 5 | lapua
# Processing Record 42 of Set 5 | matai
# Processing Record 43 of Set 5 | auki
# Processing Record 44 of Set 5 | abu kamal
# Processing Record 45 of Set 5 | general roca
# Processing Record 46 of Set 5 | avarua
# Processing Record 47 of Set 5 | oussouye
# Processing Record 48 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 5 | sao jose da coroa grande
# Processing Record 50 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 1 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 6 | santo estevao
# Processing Record 3 of Set 6 | sibolga
# Processing Record 4 of Set 6 | abnub
# Processing Record 5 of Set 6 | sfantu gheorghe
# Processing Record 6 of Set 6 | davidson
# Processing Record 7 of Set 6 | bandarbeyla
# Processing Record 8 of Set 6 | avanigadda
# Processing Record 9 of Set 6 | kodiak
# Processing Record 10 of Set 6 | maragogi
# Processing Record 11 of Set 6 | marsassoum
# Processing Record 12 of Set 6 | severo-kurilsk
# Processing Record 13 of Set 6 | mushie
# Processing Record 14 of Set 6 | victoria
# Processing Record 15 of Set 6 | manokwari
# Processing Record 16 of Set 6 | sao filipe
# Processing Record 17 of Set 6 | do gonbadan
# Processing Record 18 of Set 6 | rosarito
# Processing Record 19 of Set 6 | linjiang
# Processing Record 20 of Set 6 | patacamaya
# Processing Record 21 of Set 6 | sovetskiy
# Processing Record 22 of Set 6 | talnakh
# Processing Record 23 of Set 6 | sorong
# Processing Record 24 of Set 6 | jizan
# Processing Record 25 of Set 6 | mehran
# Processing Record 26 of Set 6 | vestmannaeyjar
# Processing Record 27 of Set 6 | floro
# Processing Record 28 of Set 6 | hurghada
# Processing Record 29 of Set 6 | tomatlan
# Processing Record 30 of Set 6 | jati
# Processing Record 31 of Set 6 | necochea
# Processing Record 32 of Set 6 | sept-iles
# Processing Record 33 of Set 6 | nhulunbuy
# Processing Record 34 of Set 6 | rostovka
# Processing Record 35 of Set 6 | tura
# Processing Record 36 of Set 6 | saint george
# Processing Record 37 of Set 6 | zhigansk
# Processing Record 38 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 6 | cidreira
# Processing Record 40 of Set 6 | meulaboh
# Processing Record 41 of Set 6 | moron
# Processing Record 42 of Set 6 | saint-georges
# Processing Record 43 of Set 6 | saint-joseph
# Processing Record 44 of Set 6 | ileza
# Processing Record 45 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 46 of Set 6 | mosquera
# Processing Record 47 of Set 6 | chimoio
# Processing Record 48 of Set 6 | yaan
# Processing Record 49 of Set 6 | trebon
# Processing Record 50 of Set 6 | la rioja
# Processing Record 1 of Set 7 | concarneau
# Processing Record 2 of Set 7 | sorland
# Processing Record 3 of Set 7 | churapcha
# Processing Record 4 of Set 7 | santiago del estero
# Processing Record 5 of Set 7 | farafangana
# Processing Record 6 of Set 7 | hasaki
# Processing Record 7 of Set 7 | tual
# Processing Record 8 of Set 7 | leh
# Processing Record 9 of Set 7 | oksfjord
# Processing Record 10 of Set 7 | nome
# Processing Record 11 of Set 7 | kyzyl-suu
# Processing Record 12 of Set 7 | shipitsyno
# Processing Record 13 of Set 7 | lavrentiya
# Processing Record 14 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 7 | dovers
# Processing Record 16 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 7 | barcelos
# Processing Record 18 of Set 7 | price
# Processing Record 19 of Set 7 | faya
# Processing Record 20 of Set 7 | san andres
# Processing Record 21 of Set 7 | nyurba
# Processing Record 22 of Set 7 | olafsvik
# Processing Record 23 of Set 7 | laguna
# Processing Record 24 of Set 7 | naze
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | saint-leu
# Processing Record 27 of Set 7 | kiunga
# Processing Record 28 of Set 7 | college
# Processing Record 29 of Set 7 | nemuro
# Processing Record 30 of Set 7 | benevento
# Processing Record 31 of Set 7 | abapo
# Processing Record 32 of Set 7 | giraltovce
# Processing Record 33 of Set 7 | kyren
# Processing Record 34 of Set 7 | dong hoi
# Processing Record 35 of Set 7 | talara
# Processing Record 36 of Set 7 | mayo
# Processing Record 37 of Set 7 | raymondville
# Processing Record 38 of Set 7 | caravelas
# Processing Record 39 of Set 7 | formosa
# Processing Record 40 of Set 7 | hobyo
# Processing Record 41 of Set 7 | kilindoni
# Processing Record 42 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 7 | atar
# Processing Record 44 of Set 7 | moerai
# Processing Record 45 of Set 7 | kalmunai
# Processing Record 46 of Set 7 | doha
# Processing Record 47 of Set 7 | parker
# Processing Record 48 of Set 7 | bonthe
# Processing Record 49 of Set 7 | puke
# Processing Record 50 of Set 7 | aasiaat
# Processing Record 1 of Set 8 | nikolskoye
# Processing Record 2 of Set 8 | sitka
# Processing Record 3 of Set 8 | skawina
# Processing Record 4 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 8 | dhidhdhoo
# Processing Record 6 of Set 8 | liberal
# Processing Record 7 of Set 8 | munak
# Processing Record 8 of Set 8 | hofn
# Processing Record 9 of Set 8 | triunfo
# Processing Record 10 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 12 of Set 8 | laem sing
# Processing Record 13 of Set 8 | chicama
# Processing Record 14 of Set 8 | sabratah
# Processing Record 15 of Set 8 | staromyshastovskaya
# Processing Record 16 of Set 8 | teya
# Processing Record 17 of Set 8 | hay river
# Processing Record 18 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 8 | bogorodskoye
# Processing Record 20 of Set 8 | basoko
# Processing Record 21 of Set 8 | mabaruma
# Processing Record 22 of Set 8 | ekhabi
# Processing Record 23 of Set 8 | chifeng
# Processing Record 24 of Set 8 | bengkulu
# Processing Record 25 of Set 8 | nishihara
# Processing Record 26 of Set 8 | hervey bay
# Processing Record 27 of Set 8 | te anau
# Processing Record 28 of Set 8 | narsaq
# Processing Record 29 of Set 8 | ahipara
# Processing Record 30 of Set 8 | kruisfontein
# Processing Record 31 of Set 8 | colares
# Processing Record 32 of Set 8 | kenora
# Processing Record 33 of Set 8 | ahuimanu
# Processing Record 34 of Set 8 | mayumba
# Processing Record 35 of Set 8 | uray
# Processing Record 36 of Set 8 | gat
# Processing Record 37 of Set 8 | ridgecrest
# Processing Record 38 of Set 8 | krasnokholmskiy
# Processing Record 39 of Set 8 | poronaysk
# Processing Record 40 of Set 8 | staryy nadym
# Processing Record 41 of Set 8 | aras
# Processing Record 42 of Set 8 | washington
# Processing Record 43 of Set 8 | manadhoo
# Processing Record 44 of Set 8 | rafaela
# Processing Record 45 of Set 8 | salmo
# Processing Record 46 of Set 8 | darhan
# Processing Record 47 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 48 of Set 8 | dunedin
# Processing Record 49 of Set 8 | moyobamba
# Processing Record 50 of Set 8 | monrovia
# Processing Record 1 of Set 9 | asfi
# Processing Record 2 of Set 9 | paka
# Processing Record 3 of Set 9 | walvis bay
# Processing Record 4 of Set 9 | tahta
# Processing Record 5 of Set 9 | stawell
# Processing Record 6 of Set 9 | mezen
# Processing Record 7 of Set 9 | alberton
# Processing Record 8 of Set 9 | mount darwin
# Processing Record 9 of Set 9 | bambanglipuro
# Processing Record 10 of Set 9 | zhanaozen
# Processing Record 11 of Set 9 | vila
# Processing Record 12 of Set 9 | namatanai
# Processing Record 13 of Set 9 | lahaina
# Processing Record 14 of Set 9 | llaillay
# Processing Record 15 of Set 9 | altona
# Processing Record 16 of Set 9 | kandrian
# Processing Record 17 of Set 9 | manzhouli
# Processing Record 18 of Set 9 | la troncal
# Processing Record 19 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 9 | leningradskiy
# Processing Record 21 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 22 of Set 9 | itacoatiara
# Processing Record 23 of Set 9 | husavik
# Processing Record 24 of Set 9 | huarmey
# Processing Record 25 of Set 9 | ust-nera
# Processing Record 26 of Set 9 | padang
# Processing Record 27 of Set 9 | sitges
# Processing Record 28 of Set 9 | mitu
# Processing Record 29 of Set 9 | namibe
# Processing Record 30 of Set 9 | manavalakurichi
# Processing Record 31 of Set 9 | shakawe
# Processing Record 32 of Set 9 | vaitape
# Processing Record 33 of Set 9 | borba
# Processing Record 34 of Set 9 | panjwin
# City not found. Skipping...
# Processing Record 35 of Set 9 | corinth
# Processing Record 36 of Set 9 | henties bay
# Processing Record 37 of Set 9 | kentau
# Processing Record 38 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 9 | hokitika
# Processing Record 40 of Set 9 | angoram
# Processing Record 41 of Set 9 | sinnamary
# Processing Record 42 of Set 9 | phetchabun
# Processing Record 43 of Set 9 | zyryanka
# Processing Record 44 of Set 9 | coihaique
# Processing Record 45 of Set 9 | belyy yar
# Processing Record 46 of Set 9 | sinop
# Processing Record 47 of Set 9 | geraldton
# Processing Record 48 of Set 9 | mildura
# Processing Record 49 of Set 9 | plyussa
# Processing Record 50 of Set 9 | burica
# City not found. Skipping...
# Processing Record 1 of Set 10 | verkh-chebula
# Processing Record 2 of Set 10 | bonavista
# Processing Record 3 of Set 10 | marzuq
# Processing Record 4 of Set 10 | iqaluit
# Processing Record 5 of Set 10 | galle
# Processing Record 6 of Set 10 | bolokhovo
# Processing Record 7 of Set 10 | panacan
# Processing Record 8 of Set 10 | anadyr
# Processing Record 9 of Set 10 | coxim
# Processing Record 10 of Set 10 | dingzhou
# Processing Record 11 of Set 10 | the pas
# Processing Record 12 of Set 10 | moose factory
# Processing Record 13 of Set 10 | orocue
# Processing Record 14 of Set 10 | san jose
# Processing Record 15 of Set 10 | bilibino
# Processing Record 16 of Set 10 | rawson
# Processing Record 17 of Set 10 | okitipupa
# Processing Record 18 of Set 10 | poso
# Processing Record 19 of Set 10 | champerico
# Processing Record 20 of Set 10 | chernyshevskiy
# Processing Record 21 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 22 of Set 10 | noumea
# Processing Record 23 of Set 10 | finschhafen
# Processing Record 24 of Set 10 | ternate
# Processing Record 25 of Set 10 | zhumadian
# Processing Record 26 of Set 10 | cockburn town
# Processing Record 27 of Set 10 | umea
# Processing Record 28 of Set 10 | half moon bay
# Processing Record 29 of Set 10 | kampene
# Processing Record 30 of Set 10 | cotoca
# Processing Record 31 of Set 10 | lalsk
# Processing Record 32 of Set 10 | kurgan
# Processing Record 33 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 10 | nouadhibou
# Processing Record 35 of Set 10 | high prairie
# Processing Record 36 of Set 10 | kailua
# Processing Record 37 of Set 10 | kupang
# Processing Record 38 of Set 10 | tabuk
# Processing Record 39 of Set 10 | mogadishu
# Processing Record 40 of Set 10 | buraydah
# Processing Record 41 of Set 10 | evensk
# Processing Record 42 of Set 10 | valmiera
# Processing Record 43 of Set 10 | deniliquin
# Processing Record 44 of Set 10 | praia da vitoria
# Processing Record 45 of Set 10 | baykit
# Processing Record 46 of Set 10 | ajaccio
# Processing Record 47 of Set 10 | neuquen
# Processing Record 48 of Set 10 | matrei
# City not found. Skipping...
# Processing Record 49 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 50 of Set 10 | kristiinankaupunki
# Processing Record 1 of Set 11 | isaka
# Processing Record 2 of Set 11 | punganuru
# Processing Record 3 of Set 11 | qui nhon
# Processing Record 4 of Set 11 | vrangel
# Processing Record 5 of Set 11 | umm lajj
# Processing Record 6 of Set 11 | kiyasovo
# Processing Record 7 of Set 11 | kamenka
# Processing Record 8 of Set 11 | morros
# Processing Record 9 of Set 11 | port hardy
# Processing Record 10 of Set 11 | dubai
# Processing Record 11 of Set 11 | benito juarez
# Processing Record 12 of Set 11 | quthing
# Processing Record 13 of Set 11 | yumen
# Processing Record 14 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 11 | paamiut
# Processing Record 16 of Set 11 | taoudenni
# Processing Record 17 of Set 11 | abu dhabi
# Processing Record 18 of Set 11 | fare
# Processing Record 19 of Set 11 | flinders
# Processing Record 20 of Set 11 | alta floresta
# Processing Record 21 of Set 11 | pemba
# Processing Record 22 of Set 11 | boulder
# Processing Record 23 of Set 11 | balkhash
# Processing Record 24 of Set 11 | kiruna
# Processing Record 25 of Set 11 | yining
# Processing Record 26 of Set 11 | linhares
# Processing Record 27 of Set 11 | bud
# Processing Record 28 of Set 11 | dubti
# Processing Record 29 of Set 11 | kiama
# Processing Record 30 of Set 11 | umuarama
# Processing Record 31 of Set 11 | aklavik
# Processing Record 32 of Set 11 | arman
# Processing Record 33 of Set 11 | teyateyaneng
# Processing Record 34 of Set 11 | rawlins
# Processing Record 35 of Set 11 | wanlaweyn
# Processing Record 36 of Set 11 | aljezur
# Processing Record 37 of Set 11 | soyo
# Processing Record 38 of Set 11 | rock sound
# Processing Record 39 of Set 11 | conceicao do araguaia
# Processing Record 40 of Set 11 | maldonado
# Processing Record 41 of Set 11 | roald
# Processing Record 42 of Set 11 | sabya
# Processing Record 43 of Set 11 | concepcion del uruguay
# Processing Record 44 of Set 11 | sao felix do xingu
# Processing Record 45 of Set 11 | jiwani
# Processing Record 46 of Set 11 | new philadelphia
# Processing Record 47 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 11 | salinopolis
# Processing Record 49 of Set 11 | dicabisagan
# Processing Record 50 of Set 11 | yar-sale
# Processing Record 1 of Set 12 | rondonopolis
# Processing Record 2 of Set 12 | maba
# Processing Record 3 of Set 12 | touros
# Processing Record 4 of Set 12 | mana
# Processing Record 5 of Set 12 | campbell river
# Processing Record 6 of Set 12 | bani walid
# Processing Record 7 of Set 12 | nalbari
# Processing Record 8 of Set 12 | menongue
# Processing Record 9 of Set 12 | caluquembe
# Processing Record 10 of Set 12 | goksun
# Processing Record 11 of Set 12 | mayor pablo lagerenza
# Processing Record 12 of Set 12 | acari
# Processing Record 13 of Set 12 | vardo
# Processing Record 14 of Set 12 | vila velha
# Processing Record 15 of Set 12 | upata
# Processing Record 16 of Set 12 | port blair
# Processing Record 17 of Set 12 | darfield
# Processing Record 18 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 12 | tiarei
# Processing Record 21 of Set 12 | corowa
# Processing Record 22 of Set 12 | ponnampet
# Processing Record 23 of Set 12 | kaliua
# Processing Record 24 of Set 12 | trenggalek
# Processing Record 25 of Set 12 | russell
# Processing Record 26 of Set 12 | trinidad
# Processing Record 27 of Set 12 | mahajanga
# Processing Record 28 of Set 12 | hopatcong
# Processing Record 29 of Set 12 | alpena
# Processing Record 30 of Set 12 | xinxiang
# Processing Record 31 of Set 12 | victor harbor
# Processing Record 32 of Set 12 | kristinehamn
# Processing Record 33 of Set 12 | purpe
# Processing Record 34 of Set 12 | oyek
# Processing Record 35 of Set 12 | preobrazheniye
# Processing Record 36 of Set 12 | belmonte
# Processing Record 37 of Set 12 | narsipatnam
# Processing Record 38 of Set 12 | svetlaya
# Processing Record 39 of Set 12 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 40 of Set 12 | tabou
# Processing Record 41 of Set 12 | kitama
# Processing Record 42 of Set 12 | pareora
# Processing Record 43 of Set 12 | cairns
# Processing Record 44 of Set 12 | gao
# Processing Record 45 of Set 12 | parabel
# Processing Record 46 of Set 12 | tanggu
# Processing Record 47 of Set 12 | hirara
# Processing Record 48 of Set 12 | ola
# Processing Record 49 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 50 of Set 12 | griffith
# Processing Record 1 of Set 13 | chute-aux-outardes
# Processing Record 2 of Set 13 | yashkul
# Processing Record 3 of Set 13 | baghdad
# Processing Record 4 of Set 13 | puerto escondido
# Processing Record 5 of Set 13 | poum
# Processing Record 6 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 7 of Set 13 | haines junction
# Processing Record 8 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 13 | kargasok
# Processing Record 10 of Set 13 | clyde river
# Processing Record 11 of Set 13 | marsh harbour
# Processing Record 12 of Set 13 | araouane
# Processing Record 13 of Set 13 | dingle
# Processing Record 14 of Set 13 | chikoy
# City not found. Skipping...
# Processing Record 15 of Set 13 | kosh-agach
# Processing Record 16 of Set 13 | goderich
# Processing Record 17 of Set 13 | amapa
# Processing Record 18 of Set 13 | romans-sur-isere
# Processing Record 19 of Set 13 | ures
# Processing Record 20 of Set 13 | canchungo
# Processing Record 21 of Set 13 | weligama
# Processing Record 22 of Set 13 | rocha
# Processing Record 23 of Set 13 | aldan
# Processing Record 24 of Set 13 | mamallapuram
# Processing Record 25 of Set 13 | acucena
# Processing Record 26 of Set 13 | portland
# Processing Record 27 of Set 13 | juba
# Processing Record 28 of Set 13 | boyolangu
# Processing Record 29 of Set 13 | aitape
# Processing Record 30 of Set 13 | berlevag
# Processing Record 31 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 13 | mackenzie
# Processing Record 33 of Set 13 | hualmay
# Processing Record 34 of Set 13 | fonte boa
# Processing Record 35 of Set 13 | lakatoro
# Processing Record 36 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 13 | eydhafushi
# Processing Record 38 of Set 13 | cukai
# Processing Record 39 of Set 13 | zheleznodorozhnyy
# Processing Record 40 of Set 13 | najran
# Processing Record 41 of Set 13 | burnie
# Processing Record 42 of Set 13 | osakarovka
# Processing Record 43 of Set 13 | igarka
# Processing Record 44 of Set 13 | goundam
# Processing Record 45 of Set 13 | rio gallegos
# Processing Record 46 of Set 13 | daxian
# City not found. Skipping...
# Processing Record 47 of Set 13 | kem
# Processing Record 48 of Set 13 | carlagan
# Processing Record 49 of Set 13 | porto novo
# Processing Record 50 of Set 13 | lima
# Processing Record 1 of Set 14 | beloha
# Processing Record 2 of Set 14 | orimattila
# Processing Record 3 of Set 14 | po
# City not found. Skipping...
# Processing Record 4 of Set 14 | sokolo
# Processing Record 5 of Set 14 | aktau
# Processing Record 6 of Set 14 | erenhot
# Processing Record 7 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 14 | pokhara
# Processing Record 9 of Set 14 | coos bay
# Processing Record 10 of Set 14 | avera
# Processing Record 11 of Set 14 | muroto
# Processing Record 12 of Set 14 | bijar
# Processing Record 13 of Set 14 | berezovyy
# Processing Record 14 of Set 14 | kaeo
# Processing Record 15 of Set 14 | turukhansk
# Processing Record 16 of Set 14 | shimoda
# Processing Record 17 of Set 14 | davila
# Processing Record 18 of Set 14 | kijang
# Processing Record 19 of Set 14 | urusha
# Processing Record 20 of Set 14 | ulundi
# Processing Record 21 of Set 14 | zwedru
# Processing Record 22 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 14 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 24 of Set 14 | sheopur
# Processing Record 25 of Set 14 | srednekolymsk
# Processing Record 26 of Set 14 | ostrovnoy
# Processing Record 27 of Set 14 | tuatapere
# Processing Record 28 of Set 14 | sur
# Processing Record 29 of Set 14 | paengaroa
# Processing Record 30 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 31 of Set 14 | seinajoki
# Processing Record 32 of Set 14 | chapais
# Processing Record 33 of Set 14 | sardinata
# Processing Record 34 of Set 14 | lerida
# Processing Record 35 of Set 14 | watertown
# Processing Record 36 of Set 14 | poplar bluff
# Processing Record 37 of Set 14 | mawlaik
# Processing Record 38 of Set 14 | nalut
# Processing Record 39 of Set 14 | west helena
# Processing Record 40 of Set 14 | manzil tamim
# City not found. Skipping...
# Processing Record 41 of Set 14 | lata
# Processing Record 42 of Set 14 | formosa do rio preto
# Processing Record 43 of Set 14 | alexandria
# Processing Record 44 of Set 14 | yangambi
# Processing Record 45 of Set 14 | skjervoy
# Processing Record 46 of Set 14 | dumka
# Processing Record 47 of Set 14 | westport
# Processing Record 48 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 14 | santa rosalia
# Processing Record 50 of Set 14 | dasoguz
# Processing Record 1 of Set 15 | narasannapeta
# Processing Record 2 of Set 15 | lages
# Processing Record 3 of Set 15 | dalby
# Processing Record 4 of Set 15 | norwich
# Processing Record 5 of Set 15 | bennington
# Processing Record 6 of Set 15 | tateyama
# Processing Record 7 of Set 15 | tumba
# Processing Record 8 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 9 of Set 15 | takanabe
# Processing Record 10 of Set 15 | pryazha
# Processing Record 11 of Set 15 | chardara
# Processing Record 12 of Set 15 | mareeba
# Processing Record 13 of Set 15 | bonoua
# Processing Record 14 of Set 15 | pierre
# Processing Record 15 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 16 of Set 15 | kinkala
# Processing Record 17 of Set 15 | alofi
# Processing Record 18 of Set 15 | luau
# Processing Record 19 of Set 15 | asmar
# Processing Record 20 of Set 15 | saint-donat-de-montcalm
# Processing Record 21 of Set 15 | derzhavinsk
# Processing Record 22 of Set 15 | warwick
# Processing Record 23 of Set 15 | ibotirama
# Processing Record 24 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 15 | livno
# Processing Record 26 of Set 15 | dudinka
# Processing Record 27 of Set 15 | lucapa
# Processing Record 28 of Set 15 | kokopo
# Processing Record 29 of Set 15 | kumbo
# Processing Record 30 of Set 15 | novosokolniki
# Processing Record 31 of Set 15 | gillette
# Processing Record 32 of Set 15 | ghatanji
# Processing Record 33 of Set 15 | biak
# Processing Record 34 of Set 15 | nanchang
# Processing Record 35 of Set 15 | lakes entrance
# Processing Record 36 of Set 15 | dnestrovsc
# Processing Record 37 of Set 15 | viru
# Processing Record 38 of Set 15 | shingu
# Processing Record 39 of Set 15 | hattem
# Processing Record 40 of Set 15 | catamarca
# Processing Record 41 of Set 15 | dekar
# Processing Record 42 of Set 15 | chemal
# Processing Record 43 of Set 15 | plast
# Processing Record 44 of Set 15 | bairiki
# Processing Record 45 of Set 15 | dusti
# Processing Record 46 of Set 15 | ouesso
# Processing Record 47 of Set 15 | fairbanks
# Processing Record 48 of Set 15 | loa janan
# Processing Record 49 of Set 15 | aborlan
# Processing Record 50 of Set 15 | suntar
# Processing Record 1 of Set 16 | awjilah
# Processing Record 2 of Set 16 | jieshi
# Processing Record 3 of Set 16 | moratuwa
# Processing Record 4 of Set 16 | inhambane
# Processing Record 5 of Set 16 | bardiyah
# Processing Record 6 of Set 16 | soc trang
# Processing Record 7 of Set 16 | tiznit
# Processing Record 8 of Set 16 | tromso
# Processing Record 9 of Set 16 | kungurtug
# Processing Record 10 of Set 16 | shchelkun
# Processing Record 11 of Set 16 | yanai
# Processing Record 12 of Set 16 | flin flon
# Processing Record 13 of Set 16 | kushima
# Processing Record 14 of Set 16 | aksaray
# Processing Record 15 of Set 16 | la palma
# Processing Record 16 of Set 16 | asilah
# Processing Record 17 of Set 16 | hashtrud
# Processing Record 18 of Set 16 | juigalpa
# Processing Record 19 of Set 16 | kemijarvi
# Processing Record 20 of Set 16 | bangassou
# Processing Record 21 of Set 16 | safaga
# Processing Record 22 of Set 16 | crotone
# Processing Record 23 of Set 16 | gizo
# Processing Record 24 of Set 16 | winslow
# Processing Record 25 of Set 16 | qaqortoq
# Processing Record 26 of Set 16 | piedade
# Processing Record 27 of Set 16 | jodar
# Processing Record 28 of Set 16 | mao
# Processing Record 29 of Set 16 | kudahuvadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Mount Isa      AU -20.7333  139.5000     82.17        17
# 1            Kahului      US  20.8947 -156.4700     80.62        71
# 2           Hoa Binh      VN  20.8133  105.3383     87.93        69
# 3           Hermanus      ZA -34.4187   19.2345     57.51        78
# 4               Chuy      UY -33.6971  -53.4616     45.05        79
# 5  Sao Joao Da Barra      BR -21.6403  -41.0511     70.92        92
# 6         Coahuayana      MX  18.7333 -103.6833     78.84        84
# 7    Arraial Do Cabo      BR -22.9661  -42.0278     69.58        93
# 8       Puerto Ayora      EC  -0.7393  -90.3518     68.56        91
# 9             Ixtapa      MX  20.7000 -105.2000     81.23        83
#
#    Cloudiness  Wind Speed Current Description
# 0           7        5.75           clear sky
# 1          20       23.02          few clouds
# 2          88        3.76          light rain
# 3          94       12.55     overcast clouds
# 4           0        6.51           clear sky
# 5          62       11.83       broken clouds
# 6          92        1.83     overcast clouds
# 7         100       17.65     overcast clouds
# 8          89        5.99     overcast clouds
# 9          40        3.44    scattered clouds

# %%
# Create the output file (CSV).

output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.

city_data_df.to_csv(output_data_file, index_label="City_ID")
